# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime
import smtplib
import csv
import pandas as pd

# %%
# Connect to website


URL = 'https://www.nykaa.com/colorbar-kiss-proof-lip-stain/p/26114?ptype=product&productId=350554&skuId=350554'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36", "Accept-Encoding": "gzip, deflate, br", "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7", "Upgrade-Insecure-Requests": "1"}
page = requests.get(URL, headers = headers)
soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
title = soup2.find("h1", attrs={"class":'css-1gc4x7i'}).text
price = soup2.find("span", attrs={"class":'css-1jczs19'}).text
discount = soup2.find("span", attrs={"class":'css-bhhehx'}).text



title = title.strip()
price = price.strip()
discount = discount.strip()

print(title)
print(price)
print(discount)
    
#today = datetime.date.today()
    
#header = ['Title', 'Price', 'Today']
#data = [title, price, today]
# Out:
# Colorbar Kiss Proof Lip Stain - Stinking Rich
#
#
#            (
#
#            6.5ml
#
#            )
# ₹760
# 20% Off

# %%
header = ['Title', 'Price', 'Discount', 'Today']

data = [title, price, discount, today]

with open(r'C:\Users\SHREYA\Desktop\AmazonWebScraping.csv','w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
today = datetime.date.today()

print(today)
# Out:
# 2023-07-17

# %%
df = pd.read_csv(r'C:\Users\SHREYA\Desktop\AmazonWebScraping.csv')
df
# Out:
#                                                 Title Price Discount  \
# 0   Colorbar Kiss Proof Lip Stain - Stinking Rich\...  ₹760  20% Off
# 1   Colorbar Kiss Proof Lip Stain - Stinking Rich\...  ₹760  20% Off
# 2   Colorbar Kiss Proof Lip Stain - Stinking Rich\...  ₹760  20% Off
# 3   Colorbar Kiss Proof Lip Stain - Stinking Rich\...  ₹760  20% Off
# 4   Colorbar Kiss Proof Lip Stain - Stinking Rich\...  ₹760  20% Off
# 5   Colorbar Kiss Proof Lip Stain - Stinking Rich\...  ₹760  20% Off
# 6   Colorbar Kiss Proof Lip Stain - Stinking Rich\...  ₹760  20% Off
# 7   Colorbar Kiss Proof Lip Stain - Stinking Rich\...  ₹760  20% Off
# 8   Colorbar Kiss Proof Lip Stain - Stinking Rich\...  ₹760  20% Off
# 9   Colorbar Kiss Proof Lip Stain - Stinking Rich\...  ₹760  20% Off
# 10  Colorbar Kiss Proof Lip Stain - Stinking Rich\...  ₹760  20% Off
# 11  Colorbar Kiss Proof Lip Stain - Stinking Rich\...  ₹760  20% Off
# 12  Colorbar Kiss Proof Lip Stain - Stinking Rich\...  ₹760  20% Off
# ...

# %%
def check_price():
    URL = 'https://www.nykaa.com/colorbar-kiss-proof-lip-stain/p/26114?ptype=product&productId=350554&skuId=350554'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36", "Accept-Encoding": "gzip, deflate, br", "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7", "Upgrade-Insecure-Requests": "1"}
    page = requests.get(URL, headers = headers)
    soup1 = BeautifulSoup(page.content, "html.parser")
    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
    title = soup2.find("h1", attrs={"class":'css-1gc4x7i'}).text
    price = soup2.find("span", attrs={"class":'css-1jczs19'}).text
    discount = soup2.find("span", attrs={"class":'css-bhhehx'}).text

    title = title.strip()
    price = price.strip()
    discount = discount.strip()
    
    import datetime
    today = datetime.date.today()
    
    import csv
    header = ['Title', 'Price', 'Discount', 'Today']
    data = [title, price, discount, today]

    with open(r'C:\Users\SHREYA\Desktop\AmazonWebScraping.csv','a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)
        
    if(discount==30):
        send_mail()

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
    server.ehlo()
    server.login('shriyahanchinal43@gmail.com', 'ShriyaH123!')
    subject = "Your lipstick with the discount of 30% Off is waiting!"
    body = "Shriya, This is the moment you have been waiting for. Your shirt is now waiting for you to buy. Hurry up and buy it!"
    msg = f"Subject: {subject}\n\n{body}"
    server.sendmail('shriyahanchinal43@gmail.com', msg)

# %%
while(True):
    check_price()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 while(True):
# ----> 2     check_price()
#       3     time.sleep(1)
#
# Cell In[2], line 4, in check_price()
#       2 URL = 'https://www.nykaa.com/colorbar-kiss-proof-lip-stain/p/26114?ptype=product&productId=350554&skuId=350554'
#       3 headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36", "Accept-Encoding": "gzip, deflate, br", "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7", "Upgrade-Insecure-Requests": "1"}
# ----> 4 page = requests.get(URL, headers = headers)
#       5 soup1 = BeautifulSoup(page.content, "html.parser")
#       6 soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
#
# ...
