# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'a61fb5ae-22d6-428f-bd8b-507d788b88e8',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df
    
    if not os.path.isfile(r'C:\Users\SHREYA\Downloads\Python Project\Crypto.csv'):
        df.to_csv(r'C:\Users\SHREYA\Downloads\Python Project\Crypto.csv', header = 'column_names')
    else:
        df.to_csv(r'C:\Users\SHREYA\Downloads\Python Project\Crypto.csv', mode = 'a', header = False)

# %%
import os
from time import time
from time import sleep
for i in range(333):
    api_runner()
    print('API runner completed!')
    sleep(3)
exit()
# Out:
# {'status': {'timestamp': '2023-07-18T16:08:56.637Z', 'error_code': 0, 'error_message': None, 'elapsed': 27, 'credit_count': 1, 'notice': None, 'total_count': 10125}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10348, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19432825, 'total_supply': 19432825, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-18T16:07:00.000Z', 'quote': {'USD': {'price': 29936.07530503161, 'volume_24h': 14711194407.512989, 'volume_change_24h': 41.4978, 'percent_change_1h': 0.19935838, 'percent_change_24h': -0.92136396, 'percent_change_7d': -2.12650659, 'percent_change_30d': 12.7833965, 'percent_change_60d': 11.26938857, 'percent_change_90d': 2.16173913, 'market_cap': 581742512589.5009, 'market_cap_dominance': 48.5681, 'fully_diluted_market_cap': 628657581405.66, 'tvl': None, 'last_updated': '2023-07-18T16:07:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 7129, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1'], 'max_supply': None, 'circulating_supply': 120200809.62935519, 'total_supply': 120200809.62935519, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-18T16:07:00.000Z', 'quote': {'USD': {'price': 1899.0243975862138, 'volume_24h': 6700189757.0722475, 'volume_change_24h': 24.4767, 'percent_change_1h': 0.13051599, 'percent_change_24h': -0.6158995, 'percent_change_7d': 1.48538656, 'percent_change_30d': 9.30467773, 'percent_change_60d': 4.51828853, 'percent_change_90d': -4.33772316, 'market_cap': 228264270095.7614, 'market_cap_dominance': 19.07, 'fully_diluted_market_cap': 228264270095.76, 'tvl': None, 'last_updated': '2023-07-18T16:07:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 57081, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 83750478228.26431, 'total_supply': 86715788906.04521, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 's ...
# C:\Users\SHREYA\AppData\Local\Temp\ipykernel_12044\3306121665.py:25: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# API runner completed!
# {'status': {'timestamp': '2023-07-18T16:09:00.360Z', 'error_code': 0, 'error_message': None, 'elapsed': 10, 'credit_count': 1, 'notice': None, 'total_count': 10125}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10348, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19432825, 'total_supply': 19432825, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-18T16:07:00.000Z', 'quote': {'USD': {'price': 29936.07530503161, 'volume_24h': 14711194407.512989, 'volume_change_24h': 41.4978, 'percent_change_1h': 0.19935838, 'percent_change_24h': -0.92136396, 'percent_change_7d': -2.12650659, 'percent_change_30d': 12.7833965, 'percent_change_60d': 11.26938857, 'percent_change_90d': 2.16173913, 'market_cap': 581742512589.5009, 'market_cap_dominance': 48.5681, 'fully_diluted_market_cap': 628657581405.66, 'tvl': None, 'last_updated': '2023-07-18T16:07:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 7129, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1'], 'max_supply': None, 'circulating_supply': 120200809.62935519, 'total_supply': 120200809.62935519, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-18T16:07:00.000Z', 'quote': {'USD': {'price': 1899.0243975862138, 'volume_24h': 6700189757.0722475, 'volume_change_24h': 24.4767, 'percent_change_1h': 0.13051599, 'percent_change_24h': -0.6158995, 'percent_change_7d': 1.48538656, 'percent_change_30d': 9.30467773, 'percent_change_60d': 4.51828853, 'percent_change_90d': -4.33772316, 'market_cap': 228264270095.7614, 'market_cap_dominance': 19.07, 'fully_diluted_market_cap': 228264270095.76, 'tvl': None, 'last_updated': '2023-07-18T16:07:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 57081, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 83750478228.26431, 'total_supply': 86715788906.04521, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 's ...
# API runner completed!
# C:\Users\SHREYA\AppData\Local\Temp\ipykernel_12044\3306121665.py:25: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# {'status': {'timestamp': '2023-07-18T16:09:03.744Z', 'error_code': 0, 'error_message': None, 'elapsed': 18, 'credit_count': 1, 'notice': None, 'total_count': 10125}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10348, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19432825, 'total_supply': 19432825, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-18T16:07:00.000Z', 'quote': {'USD': {'price': 29936.07530503161, 'volume_24h': 14711194407.512989, 'volume_change_24h': 41.4978, 'percent_change_1h': 0.19935838, 'percent_change_24h': -0.92136396, 'percent_change_7d': -2.12650659, 'percent_change_30d': 12.7833965, 'percent_change_60d': 11.26938857, 'percent_change_90d': 2.16173913, 'market_cap': 581742512589.5009, 'market_cap_dominance': 48.5681, 'fully_diluted_market_cap': 628657581405.66, 'tvl': None, 'last_updated': '2023-07-18T16:07:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 7129, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1'], 'max_supply': None, 'circulating_supply': 120200809.62935519, 'total_supply': 120200809.62935519, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-18T16:07:00.000Z', 'quote': {'USD': {'price': 1899.0243975862138, 'volume_24h': 6700189757.0722475, 'volume_change_24h': 24.4767, 'percent_change_1h': 0.13051599, 'percent_change_24h': -0.6158995, 'percent_change_7d': 1.48538656, 'percent_change_30d': 9.30467773, 'percent_change_60d': 4.51828853, 'percent_change_90d': -4.33772316, 'market_cap': 228264270095.7614, 'market_cap_dominance': 19.07, 'fully_diluted_market_cap': 228264270095.76, 'tvl': None, 'last_updated': '2023-07-18T16:07:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 57081, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 83750478228.26431, 'total_supply': 86715788906.04521, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 's ...
# API runner completed!
# C:\Users\SHREYA\AppData\Local\Temp\ipykernel_12044\3306121665.py:25: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# {'status': {'timestamp': '2023-07-18T16:09:07.163Z', 'error_code': 0, 'error_message': None, 'elapsed': 87, 'credit_count': 1, 'notice': None, 'total_count': 10125}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10348, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19432825, 'total_supply': 19432825, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-18T16:07:00.000Z', 'quote': {'USD': {'price': 29936.07530503161, 'volume_24h': 14711194407.512989, 'volume_change_24h': 41.4978, 'percent_change_1h': 0.19935838, 'percent_change_24h': -0.92136396, 'percent_change_7d': -2.12650659, 'percent_change_30d': 12.7833965, 'percent_change_60d': 11.26938857, 'percent_change_90d': 2.16173913, 'market_cap': 581742512589.5009, 'market_cap_dominance': 48.5681, 'fully_diluted_market_cap': 628657581405.66, 'tvl': None, 'last_updated': '2023-07-18T16:07:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 7129, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1'], 'max_supply': None, 'circulating_supply': 120200809.62935519, 'total_supply': 120200809.62935519, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-07-18T16:07:00.000Z', 'quote': {'USD': {'price': 1899.0243975862138, 'volume_24h': 6700189757.0722475, 'volume_change_24h': 24.4767, 'percent_change_1h': 0.13051599, 'percent_change_24h': -0.6158995, 'percent_change_7d': 1.48538656, 'percent_change_30d': 9.30467773, 'percent_change_60d': 4.51828853, 'percent_change_90d': -4.33772316, 'market_cap': 228264270095.7614, 'market_cap_dominance': 19.07, 'fully_diluted_market_cap': 228264270095.76, 'tvl': None, 'last_updated': '2023-07-18T16:07:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 57081, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 83750478228.26431, 'total_supply': 86715788906.04521, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 's ...
# API runner completed!
# C:\Users\SHREYA\AppData\Local\Temp\ipykernel_12044\3306121665.py:25: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 7
#       5     api_runner()
#       6     print('API runner completed!')
# ----> 7     sleep(3)
#       8 exit()
#
# KeyboardInterrupt:

# %%
df = pd.read_csv(r'C:\Users\SHREYA\Downloads\Python Project\Crypto.csv')
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
# Out:
# C:\Users\SHREYA\AppData\Local\Temp\ipykernel_12044\3568383724.py:3: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df2 = df.groupby('name', sort = False)[['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()

# %%
df2
# Out:
#                  quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                              0.11082                      -0.63604
# Ethereum                             0.19100                      -0.51971
# Tether                               0.00158                      -0.02640
# XRP                                  1.90281                       2.50994
# BNB                                 -0.00699                      -0.81342
# USD Coin                            -0.00036                       0.00042
# Cardano                              0.30757                      -1.69931
# Solana                              -0.21187                      -6.36443
# Dogecoin                             0.13174                      -0.88743
# TRON                                -0.10710                       0.51421
# Polygon                              0.13459                      -2.12928
# Litecoin                             0.22357                       0.19277
# Polkadot                            -0.18636                      -0.74791
# Avalanche                            0.06626                      -1.38111
# Wrapped Bitcoin                      0.13821                      -0.61059
#
#                  quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                             -1.32036                      13.30959
# Ethereum                             1.91889                      10.05494
# Tether                               0.00551                       0.02927
# XRP                                 59.97066                      55.62793
# BNB                                 -1.99313                      -2.00575
# USD Coin                            -0.00236                      -0.01438
# Cardano                              5.60156                      15.65292
# Solana                              15.73753                      62.41525
# Dogecoin                             6.19804                      10.96471
# TRON                                 3.87369                      13.55704
# Polygon                              2.22492                      23.97578
# Litecoin                            -5.93449                      18.61626
# Polkadot                             2.55790                      13.79783
# Avalanche                            4.89878                      21.79241
# Wrapped Bitcoin                     -3.35181                      13.27794
#
#                  quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                              11.82492                       2.36043
# Ethereum                              5.44752                      -3.95005
# Tether                               -0.00749                      -0.01376
# XRP                                  63.44497                      52.08601
# BNB                                 -21.90182                     -26.23519
# USD Coin                             -0.00776                       0.00907
# Cardano                             -16.51225                     -26.80544
# Solana                               24.81261                       9.54312
# Dogecoin                             -6.02972                     -22.14116
# TRON                                 13.82071                      21.76285
# Polygon                             -13.34786                     -32.39993
# Litecoin                              0.59348                      -4.33181
# Polkadot                             -1.80485                     -18.96946
# Avalanche                            -4.37596                     -28.54359
# Wrapped Bitcoin                      11.77075                       2.42045

# %%
df3 = df2.stack()
df3
# Out:
# name
# Bitcoin          quote.USD.percent_change_1h      0.11082
#                  quote.USD.percent_change_24h    -0.63604
#                  quote.USD.percent_change_7d     -1.32036
#                  quote.USD.percent_change_30d    13.30959
#                  quote.USD.percent_change_60d    11.82492
#                  quote.USD.percent_change_90d     2.36043
# Ethereum         quote.USD.percent_change_1h      0.19100
#                  quote.USD.percent_change_24h    -0.51971
#                  quote.USD.percent_change_7d      1.91889
#                  quote.USD.percent_change_30d    10.05494
#                  quote.USD.percent_change_60d     5.44752
#                  quote.USD.percent_change_90d    -3.95005
# Tether           quote.USD.percent_change_1h      0.00158
#                  quote.USD.percent_change_24h    -0.02640
#                  quote.USD.percent_change_7d      0.00551
#                  quote.USD.percent_change_30d     0.02927
#                  quote.USD.percent_change_60d    -0.00749
#                  quote.USD.percent_change_90d    -0.01376
# XRP              quote.USD.percent_change_1h      1.90281
#                  quote.USD.percent_change_24h     2.50994
#                  quote.USD.percent_change_7d     59.97066
#                  quote.USD.percent_change_30d    55.62793
#                  quote.USD.percent_change_60d    63.44497
#                  quote.USD.percent_change_90d    52.08601
# BNB              quote.USD.percent_change_1h     -0.00699
#                  quote.USD.percent_change_24h    -0.81342
#                  quote.USD.percent_change_7d     -1.99313
#                  quote.USD.percent_change_30d    -2.00575
#                  quote.USD.percent_change_60d   -21.90182
#                  quote.USD.percent_change_90d   -26.23519
# USD Coin         quote.USD.percent_change_1h     -0.00036
#                  quote.USD.percent_change_24h     0.00042
#                  quote.USD.percent_change_7d     -0.00236
#                  quote.USD.percent_change_30d    -0.01438
#                  quote.USD.percent_change_60d    -0.00776
#                  quote.USD.percent_change_90d     0.00907
# Cardano          quote.USD.percent_change_1h      0.30757
#                  quote.USD.percent_change_24h    -1.69931
#                  quote.USD.percent_change_7d      5.60156
#                  quote.USD.percent_change_30d    15.65292
#                  quote.USD.percent_change_60d   -16.51225
#                  quote.USD.percent_change_90d   -26.80544
# Solana           quote.USD.percent_change_1h     -0.21187
#                  quote.USD.percent_change_24h    -6.36443
#                  quote.USD.percent_change_7d     15.73753
#                  quote.USD.percent_change_30d    62.41525
#                  quote.USD.percent_change_60d    24.81261
#                  quote.USD.percent_change_90d     9.54312
# Dogecoin         quote.USD.percent_change_1h      0.13174
#                  quote.USD.percent_change_24h    -0.88743
#                  quote.USD.percent_change_7d      6.19804
#                  quote.USD.percent_change_30d    10.96471
#                  quote.USD.percent_change_60d    -6.02972
#                  quote.USD.percent_change_90d   -22.14116
# TRON             quote.USD.percent_change_1h     -0.10710
#                  quote.USD.percent_change_24h     0.51421
#                  quote.USD.percent_change_7d      3.87369
#                  quote.USD.percent_change_30d    13.55704
#                  quote.USD.percent_change_60d    13.82071
#                  quote.USD.percent_change_90d    21.76285
# Polygon          quote.USD.percent_change_1h      0.13459
#                  quote.USD.percent_change_24h    -2.12928
#                  quote.USD.percent_change_7d      2.22492
#                  quote.USD.percent_change_30d    23.97578
#                  quote.USD.percent_change_60d   -13.34786
#                  quote.USD.percent_change_90d   -32.39993
# Litecoin         quote.USD.percent_change_1h      0.22357
#                  quote.USD.percent_change_24h     0.19277
#                  quote.USD.percent_change_7d     -5.93449
#                  quote.USD.percent_change_30d    18.61626
#                  quote.USD.percent_change_60d     0.59348
#                  quote.USD.percent_change_90d    -4.33181
# Polkadot         quote.USD.percent_change_1h     -0.18636
#                  quote.USD.percent_change_24h    -0.74791
#                  quote.USD.percent_change_7d      2.55790
#                  quote.USD.percent_change_30d    13.79783
#                  quote.USD.percent_change_60d    -1.80485
#                  quote.USD.percent_change_90d   -18.96946
# Avalanche        quote.USD.percent_change_1h      0.06626
#                  quote.USD.percent_change_24h    -1.38111
#                  quote.USD.percent_change_7d      4.89878
#                  quote.USD.percent_change_30d    21.79241
#                  quote.USD.percent_change_60d    -4.37596
#                  quote.USD.percent_change_90d   -28.54359
# Wrapped Bitcoin  quote.USD.percent_change_1h      0.13821
#                  quote.USD.percent_change_24h    -0.61059
#                  quote.USD.percent_change_7d     -3.35181
#                  quote.USD.percent_change_30d    13.27794
#                  quote.USD.percent_change_60d    11.77075
#                  quote.USD.percent_change_90d     2.42045
# dtype: float64

# %%
type(df3)
# Out:
# pandas.core.series.Series

# %%
df4 =df3.to_frame(name = 'values')
df4
# Out:
#                                                 values
# name
# Bitcoin         quote.USD.percent_change_1h    0.11082
#                 quote.USD.percent_change_24h  -0.63604
#                 quote.USD.percent_change_7d   -1.32036
#                 quote.USD.percent_change_30d  13.30959
#                 quote.USD.percent_change_60d  11.82492
#                 quote.USD.percent_change_90d   2.36043
# Ethereum        quote.USD.percent_change_1h    0.19100
#                 quote.USD.percent_change_24h  -0.51971
#                 quote.USD.percent_change_7d    1.91889
#                 quote.USD.percent_change_30d  10.05494
#                 quote.USD.percent_change_60d   5.44752
#                 quote.USD.percent_change_90d  -3.95005
# Tether          quote.USD.percent_change_1h    0.00158
#                 quote.USD.percent_change_24h  -0.02640
#                 quote.USD.percent_change_7d    0.00551
#                 quote.USD.percent_change_30d   0.02927
#                 quote.USD.percent_change_60d  -0.00749
#                 quote.USD.percent_change_90d  -0.01376
# XRP             quote.USD.percent_change_1h    1.90281
#                 quote.USD.percent_change_24h   2.50994
#                 quote.USD.percent_change_7d   59.97066
#                 quote.USD.percent_change_30d  55.62793
#                 quote.USD.percent_change_60d  63.44497
#                 quote.USD.percent_change_90d  52.08601
# BNB             quote.USD.percent_change_1h   -0.00699
#                 quote.USD.percent_change_24h  -0.81342
#                 quote.USD.percent_change_7d   -1.99313
#                 quote.USD.percent_change_30d  -2.00575
#                 quote.USD.percent_change_60d -21.90182
#                 quote.USD.percent_change_90d -26.23519
# USD Coin        quote.USD.percent_change_1h   -0.00036
#                 quote.USD.percent_change_24h   0.00042
#                 quote.USD.percent_change_7d   -0.00236
#                 quote.USD.percent_change_30d  -0.01438
#                 quote.USD.percent_change_60d  -0.00776
#                 quote.USD.percent_change_90d   0.00907
# Cardano         quote.USD.percent_change_1h    0.30757
#                 quote.USD.percent_change_24h  -1.69931
#                 quote.USD.percent_change_7d    5.60156
#                 quote.USD.percent_change_30d  15.65292
#                 quote.USD.percent_change_60d -16.51225
#                 quote.USD.percent_change_90d -26.80544
# Solana          quote.USD.percent_change_1h   -0.21187
#                 quote.USD.percent_change_24h  -6.36443
#                 quote.USD.percent_change_7d   15.73753
#                 quote.USD.percent_change_30d  62.41525
#                 quote.USD.percent_change_60d  24.81261
#                 quote.USD.percent_change_90d   9.54312
# Dogecoin        quote.USD.percent_change_1h    0.13174
#                 quote.USD.percent_change_24h  -0.88743
#                 quote.USD.percent_change_7d    6.19804
#                 quote.USD.percent_change_30d  10.96471
#                 quote.USD.percent_change_60d  -6.02972
#                 quote.USD.percent_change_90d -22.14116
# TRON            quote.USD.percent_change_1h   -0.10710
#                 quote.USD.percent_change_24h   0.51421
#                 quote.USD.percent_change_7d    3.87369
#                 quote.USD.percent_change_30d  13.55704
#                 quote.USD.percent_change_60d  13.82071
#                 quote.USD.percent_change_90d  21.76285
# Polygon         quote.USD.percent_change_1h    0.13459
#                 quote.USD.percent_change_24h  -2.12928
#                 quote.USD.percent_change_7d    2.22492
#                 quote.USD.percent_change_30d  23.97578
#                 quote.USD.percent_change_60d -13.34786
#                 quote.USD.percent_change_90d -32.39993
# Litecoin        quote.USD.percent_change_1h    0.22357
#                 quote.USD.percent_change_24h   0.19277
#                 quote.USD.percent_change_7d   -5.93449
#                 quote.USD.percent_change_30d  18.61626
#                 quote.USD.percent_change_60d   0.59348
#                 quote.USD.percent_change_90d  -4.33181
# Polkadot        quote.USD.percent_change_1h   -0.18636
#                 quote.USD.percent_change_24h  -0.74791
#                 quote.USD.percent_change_7d    2.55790
#                 quote.USD.percent_change_30d  13.79783
#                 quote.USD.percent_change_60d  -1.80485
#                 quote.USD.percent_change_90d -18.96946
# Avalanche       quote.USD.percent_change_1h    0.06626
#                 quote.USD.percent_change_24h  -1.38111
#                 quote.USD.percent_change_7d    4.89878
#                 quote.USD.percent_change_30d  21.79241
#                 quote.USD.percent_change_60d  -4.37596
#                 quote.USD.percent_change_90d -28.54359
# Wrapped Bitcoin quote.USD.percent_change_1h    0.13821
#                 quote.USD.percent_change_24h  -0.61059
#                 quote.USD.percent_change_7d   -3.35181
#                 quote.USD.percent_change_30d  13.27794
#                 quote.USD.percent_change_60d  11.77075
#                 quote.USD.percent_change_90d   2.42045

# %%
type(df4)
# Out:
# pandas.core.frame.DataFrame

# %%
df4.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

# %%
df5 = df4.set_index(index)

# %%
df5 = df4.reset_index()

# %%
df5 = df5.rename(columns = {'level_1':'percent_change'})

# %%
df5['percent_change'] = df5['percent_change'].replace(['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d'],['1h', '24h', '7d', '30d', '60d', '90d'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x = 'percent_change', y = 'values', hue = 'name', data = df5, kind = 'point')
